# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from textblob import TextBlob 
def fetch_sentiment_using_SIA(text):
    sid = SentimentIntensityAnalyzer()
    polarity_scores = sid.polarity_scores(text)
    if polarity_scores['neg'] > polarity_scores['pos']:
        return 'negative'
    else:
        return 'positive'

def fetch_sentiment_using_textblob(text):
    analysis = TextBlob(text)
    # set sentiment 
    if analysis.sentiment.polarity >= 0:
        return 'positive'
    else: 
        return 'negative'

# %%
import pandas as pd
climate_df = pd.read_csv("climate_dataset_final_20191127-142026.csv")

# %%
climate_df.head()
# Out:
#                                                 text           created_at  \
# 0                            https://t.co/7dtHnjxSHr  2019-11-27 08:50:25
# 1              Y'all elitist bout the weirdest shit.  2019-11-27 08:50:26
# 2  Eastern Europe's Biggest NTOPCon Bifacial Sola...  2019-11-27 08:50:26
# 3  I've just posted a new blog: China says CO2 bo...  2019-11-27 08:50:27
# 4  New Solar Array to Power Dana's Toledo Operati...  2019-11-27 08:50:27
#
#    geo lang place coordinates  user.favourites_count  user.statuses_count  \
# 0  NaN  und   NaN         NaN                     48                   53
# 1  NaN   en   NaN         NaN                 101169                24474
# 2  NaN   en   NaN         NaN                   3338                63030
# 3  NaN   en   NaN         NaN                      9                 6282
# 4  NaN   en   NaN         NaN                   3338                63031
#
# ...

# %%
dataset_text = climate_df.text
dataset_text
# Out:
# 0                                  https://t.co/7dtHnjxSHr
# 1                    Y'all elitist bout the weirdest shit.
# 2        Eastern Europe's Biggest NTOPCon Bifacial Sola...
# 3        I've just posted a new blog: China says CO2 bo...
# 4        New Solar Array to Power Dana's Toledo Operati...
# 5        Ein E-Auto mit Solarzellen, das seine Energie ...
# 6        @camerondallas Hi guys, I would recommend the ...
# 7        Smoke Without Fire: The Myth of a ‘Labour Anti...
# 8        In @BWIglobal health and safety representative...
# 9        And the premium was taken but no response for ...
# 10       Sono necessari tagli alle emissioni "senza pre...
# 11       Mecury can cause brain damage, respiratory inf...
# 12       @diplomat_Style We share your concern about pl...
# 13                                           Good proeject
# 14                                            @AlanKellyTD
# 15       A 3r descobrim l’#univers, la Via Làctia, el S...
# ...

# %%
# for text in dataset_text:
#     polarity = TextBlob(text)
#     sent = polarity.sentiment
#     print(sent)
#     if sent > 0:
#         print("positive")
#     else:
#         print("negative")
def detect_polarity(text):
    return TextBlob(text).sentiment.polarity

climate_df['polarity'] = climate_df.text.apply(detect_polarity)
climate_df.head()
# Out:
#                                                 text           created_at  \
# 0                            https://t.co/7dtHnjxSHr  2019-11-27 08:50:25
# 1              Y'all elitist bout the weirdest shit.  2019-11-27 08:50:26
# 2  Eastern Europe's Biggest NTOPCon Bifacial Sola...  2019-11-27 08:50:26
# 3  I've just posted a new blog: China says CO2 bo...  2019-11-27 08:50:27
# 4  New Solar Array to Power Dana's Toledo Operati...  2019-11-27 08:50:27
#
#    geo lang place coordinates  user.favourites_count  user.statuses_count  \
# 0  NaN  und   NaN         NaN                     48                   53
# 1  NaN   en   NaN         NaN                 101169                24474
# 2  NaN   en   NaN         NaN                   3338                63030
# 3  NaN   en   NaN         NaN                      9                 6282
# 4  NaN   en   NaN         NaN                   3338                63031
#
# ...

# %%
def detect_subjective(text):
    return TextBlob(text).sentiment.subjectivity

climate_df['subjectivity'] = climate_df.text.apply(detect_subjective)
climate_df.head()
# Out:
#                                                 text           created_at  \
# 0                            https://t.co/7dtHnjxSHr  2019-11-27 08:50:25
# 1              Y'all elitist bout the weirdest shit.  2019-11-27 08:50:26
# 2  Eastern Europe's Biggest NTOPCon Bifacial Sola...  2019-11-27 08:50:26
# 3  I've just posted a new blog: China says CO2 bo...  2019-11-27 08:50:27
# 4  New Solar Array to Power Dana's Toledo Operati...  2019-11-27 08:50:27
#
#    geo lang place coordinates  user.favourites_count  user.statuses_count  \
# 0  NaN  und   NaN         NaN                     48                   53
# 1  NaN   en   NaN         NaN                 101169                24474
# 2  NaN   en   NaN         NaN                   3338                63030
# 3  NaN   en   NaN         NaN                      9                 6282
# 4  NaN   en   NaN         NaN                   3338                63031
#
# ...

# %%
sentiment_df = climate_df[['text','polarity', 'subjectivity']]
sentiment_df.head()
# if sentiment_df.polarity >0:
# Out:
#                                                 text  polarity  subjectivity
# 0                            https://t.co/7dtHnjxSHr  0.000000      0.000000
# 1              Y'all elitist bout the weirdest shit. -0.200000      0.800000
# 2  Eastern Europe's Biggest NTOPCon Bifacial Sola...  0.000000      0.000000
# 3  I've just posted a new blog: China says CO2 bo...  0.068182      0.227273
# 4  New Solar Array to Power Dana's Toledo Operati...  0.136364      0.454545

# %%
def sentiment(number):
    if number > 0:
        return "positve"
    elif number == 0: 
        return "neutral"
    else:
        return "negative"
    
#     return TextBlob(text).sentiment.subjectivity

climate_df['sentiment'] = climate_df.polarity.apply(sentiment)
climate_df.head()
# Out:
#                                                 text           created_at  \
# 0                            https://t.co/7dtHnjxSHr  2019-11-27 08:50:25
# 1              Y'all elitist bout the weirdest shit.  2019-11-27 08:50:26
# 2  Eastern Europe's Biggest NTOPCon Bifacial Sola...  2019-11-27 08:50:26
# 3  I've just posted a new blog: China says CO2 bo...  2019-11-27 08:50:27
# 4  New Solar Array to Power Dana's Toledo Operati...  2019-11-27 08:50:27
#
#    geo lang place coordinates  user.favourites_count  user.statuses_count  \
# 0  NaN  und   NaN         NaN                     48                   53
# 1  NaN   en   NaN         NaN                 101169                24474
# 2  NaN   en   NaN         NaN                   3338                63030
# 3  NaN   en   NaN         NaN                      9                 6282
# 4  NaN   en   NaN         NaN                   3338                63031
#
# ...

# %%
sentiment_df = climate_df[['text','sentiment']]
sentiment_df.head()
# Out:
#                                                 text sentiment
# 0                            https://t.co/7dtHnjxSHr   neutral
# 1              Y'all elitist bout the weirdest shit.  negative
# 2  Eastern Europe's Biggest NTOPCon Bifacial Sola...   neutral
# 3  I've just posted a new blog: China says CO2 bo...   positve
# 4  New Solar Array to Power Dana's Toledo Operati...   positve
