# %%
import tweepy
from tweepy import OAuthHandler
import json
import jsonlines
import pandas as pd
from pandas import DataFrame
import csv

from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import time
import csv
import sys

# %%
# consumer_key = '3tttlV4FpILBBCWyGqEmkAciQ'
# consumer_secret = 'RyZgTfcQ4fWKbn5C3UqKkYkjSl7J905RGazgCA2epu4V9LDNQM'
# access_key = '1028127692376498176-vlyKhBb4Oqto854u3x6hO9rUh50qtk'
# access_secret = 'AAmQcYa62lCYmRofVpf8nnaKFQCbVsH5N9lf0dunZzNsS'

# %%
# Create a streamer object
class StdOutListener(StreamListener):
    
    # Define a function that is initialized when the miner is called
    def __init__(self, api = None):
        # That sets the api
        self.api = api
        # Create a file with 'data_' and the current time
        self.filename = 'climate_dataset_final'+'_'+time.strftime('%Y%m%d-%H%M%S')+'.csv'
        # Create a new file with that filename
        csvFile = open(self.filename, 'w')
        
        # Create a csv writer
        csvWriter = csv.writer(csvFile)
        
        # Write a single row with the headers of the columns
        csvWriter.writerow(['text',
                            'created_at',
                            'geo',
                            'lang',
                            'place',
                            'coordinates',
                            'user.favourites_count',
                            'user.statuses_count',
                            'user.description',
                            'user.location',
                            'user.id',
                            'user.created_at',
                            'user.verified',
                            'user.following',
                            'user.url',
                            'user.listed_count',
                            'user.followers_count',
                            'user.default_profile_image',
                            'user.utc_offset',
                            'user.friends_count',
                            'user.default_profile',
                            'user.name',
                            'user.lang',
                            'user.screen_name',
                            'user.geo_enabled',
                            'user.profile_background_color',
                            'user.profile_image_url',
                            'user.time_zone',
                            'id',
                            'favorite_count',
                            'retweeted',
                            'source',
                            'favorited',
                            'retweet_count'])

    # When a tweet appears
    def on_status(self, status):
        
        # Open the csv file created previously
        csvFile = open(self.filename, 'a')
        
        # Create a csv writer
        csvWriter = csv.writer(csvFile)
        
        # If the tweet is not a retweet
        if not 'RT @' in status.text:
            # Try to 
            try:
                # Write the tweet's information to the csv file
                csvWriter.writerow([status.text,
                                    status.created_at,
                                    status.geo,
                                    status.lang,
                                    status.place,
                                    status.coordinates,
                                    status.user.favourites_count,
                                    status.user.statuses_count,
                                    status.user.description,
                                    status.user.location,
                                    status.user.id,
                                    status.user.created_at,
                                    status.user.verified,
                                    status.user.following,
                                    status.user.url,
                                    status.user.listed_count,
                                    status.user.followers_count,
                                    status.user.default_profile_image,
                                    status.user.utc_offset,
                                    status.user.friends_count,
                                    status.user.default_profile,
                                    status.user.name,
                                    status.user.lang,
                                    status.user.screen_name,
                                    status.user.geo_enabled,
                                    status.user.profile_background_color,
                                    status.user.profile_image_url,
                                    status.user.time_zone,
                                    status.id,
                                    status.favorite_count,
                                    status.retweeted,
                                    status.source,
                                    status.favorited,
                                    status.retweet_count])
            # If some error occurs
            except Exception as e:
                # Print the error
                print(e)
                # and continue
                pass
            
        # Close the csv file
        csvFile.close()

        # Return nothing
        return

    # When an error occurs
    def on_error(self, status_code):
        # Print the error code
        print('Encountered error with status code:', status_code)
        
        # If the error code is 401, which is the error for bad credentials
        if status_code == 401:
            # End the stream
            return False

    # When a deleted tweet appears
    def on_delete(self, status_id, user_id):
        
        # Print message
        print("Delete notice")
        
        # Return nothing
        return

    # When reach the rate limit
    def on_limit(self, track):
        
        # Print rate limiting error
        print("Rate limited, continuing")
        
        # Continue mining tweets
        return True

    # When timed out
    def on_timeout(self):
        
        # Print timeout message
        print(sys.stderr, 'Timeout...')
        
        # Wait 10 seconds
        time.sleep(10)
        
        # Return nothing
        return

# %%
# Create a mining function
def start_mining(queries):
    '''
    Inputs list of strings. Returns tweets containing those strings.
    '''
    
    #Variables that contains the user credentials to access Twitter API
    
    consumer_key = '3tttlV4FpILBBCWyGqEmkAciQ'
    consumer_secret = 'RyZgTfcQ4fWKbn5C3UqKkYkjSl7J905RGazgCA2epu4V9LDNQM'
    access_token = '1028127692376498176-vlyKhBb4Oqto854u3x6hO9rUh50qtk'
    access_token_secret = 'AAmQcYa62lCYmRofVpf8nnaKFQCbVsH5N9lf0dunZzNsS'
#     consumer_key = "YOUR_CREDENTIALS"
#     consumer_secret = "YOUR_CREDENTIALS"
#     access_token = "YOUR_CREDENTIALS"
#     access_token_secret = "YOUR_CREDENTIALS"

    # Create a listener
    l = StdOutListener()
    
    # Create authorization info
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    
    # Create a stream object with listener and authorization
    stream = Stream(auth, l)

    # Run the stream object using the user defined queries
    stream.filter(track=queries)

# %%
start_mining(['Carbon free','solar' ,'global climate change', 'wind speed', 'slash and burn', 'crop burning', 'amazon fires', 'smoke', 'contamination', 'polluted', 'plastic', 'polluted Ganga', 'submerge', 'coastal areas', 'climate emergency', 'alarmism', 'environmental defence', 'climate strike', 'smog', 'breathing issues', 'greenhouse gas', 'health', 'air quality', 'fish', 'extinct', 'whales', 'sharks', 'greenhouse effect', 'CFCs', 'emission', 'carbon footprint', 'respiratory diseases', 'fossil fuels' ])
# Out:
# 'charmap' codec can't encode character '\U0001f342' in position 219: character maps to <undefined>
# 'charmap' codec can't encode characters in position 325-326: character maps to <undefined>
# 'charmap' codec can't encode character '\u231a' in position 94: character maps to <undefined>
# 'charmap' codec can't encode characters in position 231-232: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f60d' in position 58: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f47b' in position 103: character maps to <undefined>
# 'charmap' codec can't encode characters in position 185-186: character maps to <undefined>
# 'charmap' codec can't encode character '\u2728' in position 226: character maps to <undefined>
# 'charmap' codec can't encode characters in position 1-14: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f389' in position 43: character maps to <undefined>
# 'charmap' codec can't encode characters in position 135-136: character maps to <undefined>
# 'charmap' codec can't encode character '\u039f' in position 531: character maps to <undefined>
# 'charmap' codec can't encode characters in position 311-316: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f0cf' in position 143: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f4f8' in position 0: character maps to <undefined>
# 'charmap' codec can't encode character '\u010d' in position 423: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f343' in position 154: character maps to <undefined>
# 'charmap' codec can't encode characters in position 1-2: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f614' in position 230: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f52e' in position 127: character maps to <undefined>
# 'charmap' codec can't encode characters in position 92-95: character maps to <undefined>
# 'charmap' codec can't encode characters in position 237-239: character maps to <undefined>
# 'charmap' codec can't encode characters in position 181-182: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f449' in position 1: character maps to <undefined>
# 'charmap' codec can't encode characters in position 90-91: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f5a4' in position 194: character maps to <undefined>
# 'charmap' codec can't encode characters in position 205-209: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f338' in position 59: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f42c' in position 407: character maps to <undefined>
# 'charmap' codec can't encode characters in position 180-185: character maps to <undefined>
# 'charmap' codec can't encode characters in position 101-102: character maps to <undefined>
# 'charmap' codec can't encode characters in position 8-13: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f50a' in position 59: character maps to <undefined>
# 'charmap' codec can't encode characters in position 1-8: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f48b' in position 203: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f445' in position 161: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f449' in position 95: character maps to <undefined>
# 'charmap' codec can't encode characters in position 87-88: character maps to <undefined>
# 'charmap' codec can't encode characters in position 120-125: character maps to <undefined>
# 'charmap' codec can't encode characters in position 44-47: character maps to <undefined>
# 'charmap' codec can't encode characters in position 1-7: character maps to <undefined>
# 'charmap' codec can't encode character '\u24d2' in position 480: character maps to <undefined>
# 'charmap' codec can't encode characters in position 189-195: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f494' in position 475: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f499' in position 56: character maps to <undefined>
# 'charmap' codec can't encode character '\u272d' in position 102: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f621' in position 106: character maps to <undefined>
# 'charmap' codec can't encode characters in position 215-216: character maps to <undefined>
# 'charmap' codec can't encode characters in position 87-92: character maps to <undefined>
# 'charmap' codec can't encode characters in position 118-120: character maps to <undefined>
# 'charmap' codec can't encode characters in position 1-11: character maps to <undefined>
# 'charmap' codec can't encode characters in position 170-171: character maps to <undefined>
# 'charmap' codec can't encode character '\u0442' in position 60: character maps to <undefined>
# 'charmap' codec can't encode characters in position 365-370: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f49e' in position 394: character maps to <undefined>
# 'charmap' codec can't encode characters in position 25-26: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f49a' in position 113: character maps to <undefined>
# 'charmap' codec can't encode character '\u2661' in position 251: character maps to <undefined>
# 'charmap' codec can't encode characters in position 14-17: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f383' in position 127: character maps to <undefined>
# 'charmap' codec can't encode characters in position 113-114: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f49d' in position 40: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f4a8' in position 17: character maps to <undefined>
# 'charmap' codec can't encode characters in position 57-62: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f4d4' in position 63: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f339' in position 283: character maps to <undefined>
# 'charmap' codec can't encode characters in position 128-130: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f60e' in position 401: character maps to <undefined>
# 'charmap' codec can't encode characters in position 464-465: character maps to <undefined>
# 'charmap' codec can't encode characters in position 1-32: character maps to <undefined>
# 'charmap' codec can't encode characters in position 455-456: character maps to <undefined>
# 'charmap' codec can't encode character '\u272d' in position 107: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f982' in position 62: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f525' in position 34: character maps to <undefined>
# 'charmap' codec can't encode character '\u2066' in position 59: character maps to <undefined>
# 'charmap' codec can't encode characters in position 0-6: character maps to <undefined>
# 'charmap' codec can't encode characters in position 38-52: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f432' in position 639: character maps to <undefined>
# 'charmap' codec can't encode character '\u30c4' in position 121: character maps to <undefined>
# 'charmap' codec can't encode characters in position 0-10: character maps to <undefined>
# 'charmap' codec can't encode characters in position 197-199: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001d644' in position 100: character maps to <undefined>
# 'charmap' codec can't encode characters in position 8-13: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f495' in position 50: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f447' in position 283: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f5e3' in position 12: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f60e' in position 285: character maps to <undefined>
# 'charmap' codec can't encode character '\u021b' in position 6: character maps to <undefined>
# 'charmap' codec can't encode characters in position 229-230: character maps to <undefined>
# 'charmap' codec can't encode characters in position 341-342: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f970' in position 107: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f969' in position 212: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f44d' in position 341: character maps to <undefined>
# 'charmap' codec can't encode characters in position 0-3: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f4a5' in position 107: character maps to <undefined>
# 'charmap' codec can't encode character '\u272d' in position 92: character maps to <undefined>
# 'charmap' codec can't encode characters in position 0-2: character maps to <undefined>
# 'charmap' codec can't encode characters in position 433-436: character maps to <undefined>
# 'charmap' codec can't encode characters in position 107-108: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f301' in position 207: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f420' in position 115: character maps to <undefined>
# 'charmap' codec can't encode characters in position 288-289: character maps to <undefined>
# 'charmap' codec can't encode characters in position 42-48: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f5a4' in position 336: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f33b' in position 70: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f4cd' in position 81: character maps to <undefined>
# 'charmap' codec can't encode character '\u2661' in position 466: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f602' in position 38: character maps to <undefined>
# 'charmap' codec can't encode characters in position 8-13: character maps to <undefined>
# 'charmap' codec can't encode characters in position 166-167: character maps to <undefined>
# 'charmap' codec can't encode character '\u1ea3' in position 174: character maps to <undefined>
# 'charmap' codec can't encode characters in position 334-335: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f600' in position 66: character maps to <undefined>
# 'charmap' codec can't encode characters in position 13-14: character maps to <undefined>
# 'charmap' codec can't encode characters in position 73-75: character maps to <undefined>
# 'charmap' codec can't encode characters in position 1-4: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f334' in position 474: character maps to <undefined>
# 'charmap' codec can't encode characters in position 1-15: character maps to <undefined>
# 'charmap' codec can't encode characters in position 80-82: character maps to <undefined>
# 'charmap' codec can't encode characters in position 0-22: character maps to <undefined>
# 'charmap' codec can't encode characters in position 1-4: character maps to <undefined>
# 'charmap' codec can't encode characters in position 191-192: character maps to <undefined>
# 'charmap' codec can't encode characters in position 74-77: character maps to <undefined>
# 'charmap' codec can't encode characters in position 348-350: character maps to <undefined>
# 'charmap' codec can't encode characters in position 568-569: character maps to <undefined>
# 'charmap' codec can't encode characters in position 352-356: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f440' in position 14: character maps to <undefined>
# 'charmap' codec can't encode characters in position 247-249: character maps to <undefined>
# 'charmap' codec can't encode characters in position 179-183: character maps to <undefined>
# 'charmap' codec can't encode characters in position 425-432: character maps to <undefined>
# 'charmap' codec can't encode character '\u272d' in position 96: character maps to <undefined>
# 'charmap' codec can't encode characters in position 70-72: character maps to <undefined>
# 'charmap' codec can't encode character '\u2728' in position 259: character maps to <undefined>
# 'charmap' codec can't encode character '\u25e4' in position 385: character maps to <undefined>
# 'charmap' codec can't encode character '\u0119' in position 6: character maps to <undefined>
# 'charmap' codec can't encode characters in position 265-266: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f923' in position 126: character maps to <undefined>
# 'charmap' codec can't encode characters in position 232-233: character maps to <undefined>
# 'charmap' codec can't encode characters in position 308-313: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f625' in position 28: character maps to <undefined>
# 'charmap' codec can't encode characters in position 60-61: character maps to <undefined>
# 'charmap' codec can't encode characters in position 1-5: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f644' in position 28: character maps to <undefined>
# 'charmap' codec can't encode characters in position 0-4: character maps to <undefined>
# 'charmap' codec can't encode characters in position 148-149: character maps to <undefined>
# 'charmap' codec can't encode characters in position 0-4: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f310' in position 176: character maps to <undefined>
# 'charmap' codec can't encode character '\u2066' in position 114: character maps to <undefined>
# 'charmap' codec can't encode characters in position 12-15: character maps to <undefined>
# 'charmap' codec can't encode characters in position 13-48: character maps to <undefined>
# 'charmap' codec can't encode characters in position 0-29: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f408' in position 266: character maps to <undefined>
# 'charmap' codec can't encode characters in position 87-112: character maps to <undefined>
# 'charmap' codec can't encode characters in position 177-181: character maps to <undefined>
# 'charmap' codec can't encode characters in position 0-17: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f918' in position 169: character maps to <undefined>
# 'charmap' codec can't encode characters in position 12-36: character maps to <undefined>
# 'charmap' codec can't encode characters in position 176-179: character maps to <undefined>
# 'charmap' codec can't encode characters in position 301-302: character maps to <undefined>
# 'charmap' codec can't encode characters in position 1-2: character maps to <undefined>
# 'charmap' codec can't encode characters in position 207-208: character maps to <undefined>
# 'charmap' codec can't encode characters in position 147-148: character maps to <undefined>
# 'charmap' codec can't encode character '\ufe6a' in position 53: character maps to <undefined>
# 'charmap' codec can't encode character '\u2726' in position 69: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f36a' in position 168: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f48b' in position 203: character maps to <undefined>
# 'charmap' codec can't encode character '\u231a' in position 98: character maps to <undefined>
# 'charmap' codec can't encode characters in position 179-180: character maps to <undefined>
# 'charmap' codec can't encode characters in position 168-170: character maps to <undefined>
# 'charmap' codec can't encode character '\u272d' in position 101: character maps to <undefined>
# 'charmap' codec can't encode characters in position 179-181: character maps to <undefined>
# 'charmap' codec can't encode characters in position 174-175: character maps to <undefined>
# 'charmap' codec can't encode characters in position 192-193: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f61c' in position 52: character maps to <undefined>
# 'charmap' codec can't encode characters in position 290-291: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f600' in position 84: character maps to <undefined>
# 'charmap' codec can't encode characters in position 68-69: character maps to <undefined>
# 'charmap' codec can't encode characters in position 240-241: character maps to <undefined>
# 'charmap' codec can't encode characters in position 149-152: character maps to <undefined>
# 'charmap' codec can't encode character '\u26f8' in position 736: character maps to <undefined>
# 'charmap' codec can't encode characters in position 8-9: character maps to <undefined>
# 'charmap' codec can't encode characters in position 488-489: character maps to <undefined>
# 'charmap' codec can't encode characters in position 88-90: character maps to <undefined>
# 'charmap' codec can't encode characters in position 8-13: character maps to <undefined>
# 'charmap' codec can't encode characters in position 321-322: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f30e' in position 90: character maps to <undefined>
# 'charmap' codec can't encode character '\u2066' in position 113: character maps to <undefined>
# 'charmap' codec can't encode characters in position 180-181: character maps to <undefined>
# 'charmap' codec can't encode characters in position 76-77: character maps to <undefined>
# 'charmap' codec can't encode character '\u270a' in position 210: character maps to <undefined>
# 'charmap' codec can't encode character '\u272d' in position 94: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f577' in position 372: character maps to <undefined>
# 'charmap' codec can't encode characters in position 79-80: character maps to <undefined>
# 'charmap' codec can't encode characters in position 136-139: character maps to <undefined>
# 'charmap' codec can't encode characters in position 7-9: character maps to <undefined>
# 'charmap' codec can't encode characters in position 1-12: character maps to <undefined>
# 'charmap' codec can't encode characters in position 232-276: character maps to <undefined>
# 'charmap' codec can't encode characters in position 177-204: character maps to <undefined>
# 'charmap' codec can't encode characters in position 106-107: character maps to <undefined>
# 'charmap' codec can't encode characters in position 36-37: character maps to <undefined>
# 'charmap' codec can't encode characters in position 209-210: character maps to <undefined>
# 'charmap' codec can't encode characters in position 3-8: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f495' in position 24: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f49a' in position 421: character maps to <undefined>
# 'charmap' codec can't encode characters in position 668-669: character maps to <undefined>
# 'charmap' codec can't encode characters in position 14-15: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f602' in position 57: character maps to <undefined>
# 'charmap' codec can't encode characters in position 194-200: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f60e' in position 325: character maps to <undefined>
# 'charmap' codec can't encode characters in position 1-37: character maps to <undefined>
# 'charmap' codec can't encode characters in position 177-178: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f60d' in position 219: character maps to <undefined>
# 'charmap' codec can't encode characters in position 108-114: character maps to <undefined>
# 'charmap' codec can't encode characters in position 291-294: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f947' in position 218: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f412' in position 212: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f643' in position 29: character maps to <undefined>
# 'charmap' codec can't encode characters in position 257-258: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f633' in position 21: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f974' in position 96: character maps to <undefined>
# 'charmap' codec can't encode characters in position 198-199: character maps to <undefined>
# 'charmap' codec can't encode characters in position 69-72: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f44c' in position 57: character maps to <undefined>
# 'charmap' codec can't encode characters in position 173-174: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001fa90' in position 141: character maps to <undefined>
# 'charmap' codec can't encode character '\u20e3' in position 43: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f648' in position 95: character maps to <undefined>
# 'charmap' codec can't encode characters in position 260-261: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f929' in position 47: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f438' in position 1: character maps to <undefined>
# 'charmap' codec can't encode character '\u2740' in position 316: character maps to <undefined>
# 'charmap' codec can't encode characters in position 204-206: character maps to <undefined>
# 'charmap' codec can't encode characters in position 325-330: character maps to <undefined>
# 'charmap' codec can't encode characters in position 56-58: character maps to <undefined>
# 'charmap' codec can't encode characters in position 0-8: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f337' in position 298: character maps to <undefined>
# 'charmap' codec can't encode characters in position 106-112: character maps to <undefined>
# 'charmap' codec can't encode characters in position 126-127: character maps to <undefined>
# 'charmap' codec can't encode characters in position 339-340: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f577' in position 372: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f49b' in position 282: character maps to <undefined>
# 'charmap' codec can't encode characters in position 0-3: character maps to <undefined>
# 'charmap' codec can't encode characters in position 44-45: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f3ae' in position 179: character maps to <undefined>
# 'charmap' codec can't encode characters in position 280-281: character maps to <undefined>
# 'charmap' codec can't encode character '\u272d' in position 99: character maps to <undefined>
# 'charmap' codec can't encode characters in position 168-172: character maps to <undefined>
# 'charmap' codec can't encode characters in position 11-14: character maps to <undefined>
# 'charmap' codec can't encode characters in position 517-518: character maps to <undefined>
# 'charmap' codec can't encode character '\u2800' in position 177: character maps to <undefined>
# 'charmap' codec can't encode characters in position 168-169: character maps to <undefined>
# 'charmap' codec can't encode characters in position 293-294: character maps to <undefined>
# 'charmap' codec can't encode characters in position 365-366: character maps to <undefined>
# 'charmap' codec can't encode characters in position 460-464: character maps to <undefined>
# 'charmap' codec can't encode character '\u2066' in position 1: character maps to <undefined>
# 'charmap' codec can't encode characters in position 81-83: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f4a6' in position 411: character maps to <undefined>
# 'charmap' codec can't encode characters in position 729-730: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f4af' in position 211: character maps to <undefined>
# 'charmap' codec can't encode characters in position 243-247: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f454' in position 240: character maps to <undefined>
# 'charmap' codec can't encode characters in position 85-88: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001d43c' in position 180: character maps to <undefined>
# 'charmap' codec can't encode character '\u2766' in position 390: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f4a1' in position 191: character maps to <undefined>
# 'charmap' codec can't encode characters in position 142-143: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f943' in position 111: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f980' in position 216: character maps to <undefined>
# 'charmap' codec can't encode characters in position 66-68: character maps to <undefined>
# 'charmap' codec can't encode characters in position 174-175: character maps to <undefined>
# 'charmap' codec can't encode characters in position 12-37: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f602' in position 34: character maps to <undefined>
# 'charmap' codec can't encode characters in position 272-273: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f924' in position 40: character maps to <undefined>
# 'charmap' codec can't encode character '\u2716' in position 98: character maps to <undefined>
# 'charmap' codec can't encode characters in position 1-9: character maps to <undefined>
# 'charmap' codec can't encode character '\u26a1' in position 187: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f6a8' in position 16: character maps to <undefined>
# 'charmap' codec can't encode characters in position 321-328: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f499' in position 680: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f49c' in position 399: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f9e1' in position 180: character maps to <undefined>
# 'charmap' codec can't encode character '\u25de' in position 168: character maps to <undefined>
# 'charmap' codec can't encode characters in position 107-108: character maps to <undefined>
# 'charmap' codec can't encode characters in position 180-183: character maps to <undefined>
# 'charmap' codec can't encode characters in position 110-111: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f337' in position 87: character maps to <undefined>
# 'charmap' codec can't encode characters in position 0-5: character maps to <undefined>
# 'charmap' codec can't encode character '\u272d' in position 106: character maps to <undefined>
# 'charmap' codec can't encode characters in position 142-143: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f914' in position 32: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f549' in position 170: character maps to <undefined>
# 'charmap' codec can't encode characters in position 220-221: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f3c6' in position 215: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f954' in position 134: character maps to <undefined>
# 'charmap' codec can't encode characters in position 65-66: character maps to <undefined>
# 'charmap' codec can't encode character '\u3161' in position 107: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f919' in position 676: character maps to <undefined>
# 'charmap' codec can't encode characters in position 114-115: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f30f' in position 318: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f914' in position 50: character maps to <undefined>
# 'charmap' codec can't encode characters in position 177-212: character maps to <undefined>
# 'charmap' codec can't encode characters in position 413-414: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f33b' in position 178: character maps to <undefined>
# 'charmap' codec can't encode characters in position 158-159: character maps to <undefined>
# 'charmap' codec can't encode characters in position 59-61: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f923' in position 38: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f943' in position 234: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f601' in position 328: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f986' in position 192: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f923' in position 26: character maps to <undefined>
# 'charmap' codec can't encode characters in position 209-212: character maps to <undefined>
# 'charmap' codec can't encode characters in position 164-172: character maps to <undefined>
# 'charmap' codec can't encode character '\u2661' in position 150: character maps to <undefined>
# 'charmap' codec can't encode characters in position 121-125: character maps to <undefined>
# 'charmap' codec can't encode characters in position 14-17: character maps to <undefined>
# 'charmap' codec can't encode characters in position 176-178: character maps to <undefined>
# 'charmap' codec can't encode characters in position 89-90: character maps to <undefined>
# 'charmap' codec can't encode characters in position 242-243: character maps to <undefined>
# 'charmap' codec can't encode characters in position 0-10: character maps to <undefined>
# 'charmap' codec can't encode characters in position 8-9: character maps to <undefined>
# 'charmap' codec can't encode characters in position 0-12: character maps to <undefined>
# 'charmap' codec can't encode characters in position 148-160: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f30a' in position 200: character maps to <undefined>
# 'charmap' codec can't encode character '\u2708' in position 111: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f985' in position 208: character maps to <undefined>
# 'charmap' codec can't encode characters in position 30-32: character maps to <undefined>
# 'charmap' codec can't encode character '\u272a' in position 476: character maps to <undefined>
# 'charmap' codec can't encode character '\u6b73' in position 187: character maps to <undefined>
# 'charmap' codec can't encode characters in position 1-29: character maps to <undefined>
# 'charmap' codec can't encode characters in position 117-137: character maps to <undefined>
# 'charmap' codec can't encode characters in position 173-175: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f637' in position 40: character maps to <undefined>
# 'charmap' codec can't encode characters in position 302-308: character maps to <undefined>
# 'charmap' codec can't encode characters in position 237-241: character maps to <undefined>
# 'charmap' codec can't encode characters in position 104-107: character maps to <undefined>
# 'charmap' codec can't encode characters in position 265-266: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f5a5' in position 560: character maps to <undefined>
# 'charmap' codec can't encode characters in position 252-254: character maps to <undefined>
# 'charmap' codec can't encode characters in position 450-451: character maps to <undefined>
# 'charmap' codec can't encode characters in position 197-198: character maps to <undefined>
# 'charmap' codec can't encode character '\u2615' in position 16: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f418' in position 182: character maps to <undefined>
# 'charmap' codec can't encode characters in position 71-72: character maps to <undefined>
# 'charmap' codec can't encode characters in position 13-16: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f34b' in position 378: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f983' in position 24: character maps to <undefined>
# 'charmap' codec can't encode characters in position 105-112: character maps to <undefined>
# 'charmap' codec can't encode characters in position 268-269: character maps to <undefined>
# 'charmap' codec can't encode characters in position 73-74: character maps to <undefined>
# 'charmap' codec can't encode characters in position 303-305: character maps to <undefined>
# 'charmap' codec can't encode characters in position 144-149: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f64f' in position 13: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f495' in position 112: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f451' in position 732: character maps to <undefined>
# 'charmap' codec can't encode characters in position 105-112: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f601' in position 112: character maps to <undefined>
# 'charmap' codec can't encode characters in position 41-46: character maps to <undefined>
# 'charmap' codec can't encode characters in position 291-298: character maps to <undefined>
# 'charmap' codec can't encode characters in position 198-203: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f494' in position 56: character maps to <undefined>
# 'charmap' codec can't encode character '\u2654' in position 407: character maps to <undefined>
# 'charmap' codec can't encode characters in position 139-140: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f600' in position 333: character maps to <undefined>
# 'charmap' codec can't encode characters in position 1-2: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f4ab' in position 254: character maps to <undefined>
# 'charmap' codec can't encode characters in position 0-2: character maps to <undefined>
# 'charmap' codec can't encode characters in position 69-70: character maps to <undefined>
# 'charmap' codec can't encode character '\u2b55' in position 207: character maps to <undefined>
# 'charmap' codec can't encode characters in position 472-478: character maps to <undefined>
# 'charmap' codec can't encode characters in position 1-15: character maps to <undefined>
# 'charmap' codec can't encode characters in position 0-1: character maps to <undefined>
# 'charmap' codec can't encode character '\u2764' in position 131: character maps to <undefined>
# 'charmap' codec can't encode characters in position 183-187: character maps to <undefined>
# 'charmap' codec can't encode characters in position 367-376: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f338' in position 299: character maps to <undefined>
# 'charmap' codec can't encode characters in position 416-417: character maps to <undefined>
# 'charmap' codec can't encode characters in position 258-261: character maps to <undefined>
# 'charmap' codec can't encode characters in position 130-131: character maps to <undefined>
# 'charmap' codec can't encode characters in position 58-59: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f54a' in position 160: character maps to <undefined>
# 'charmap' codec can't encode characters in position 60-61: character maps to <undefined>
# 'charmap' codec can't encode characters in position 120-121: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f36c' in position 316: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f4ba' in position 75: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f965' in position 149: character maps to <undefined>
# 'charmap' codec can't encode character '\u2728' in position 188: character maps to <undefined>
# 'charmap' codec can't encode character '\u0219' in position 16: character maps to <undefined>
# 'charmap' codec can't encode characters in position 51-52: character maps to <undefined>
# 'charmap' codec can't encode characters in position 204-213: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f642' in position 51: character maps to <undefined>
# 'charmap' codec can't encode character '\u20bf' in position 292: character maps to <undefined>
# 'charmap' codec can't encode characters in position 218-223: character maps to <undefined>
# 'charmap' codec can't encode characters in position 867-872: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f335' in position 267: character maps to <undefined>
# 'charmap' codec can't encode character '\u21aa' in position 73: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f41d' in position 341: character maps to <undefined>
# 'charmap' codec can't encode characters in position 616-621: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f30f' in position 196: character maps to <undefined>
# 'charmap' codec can't encode characters in position 89-93: character maps to <undefined>
# 'charmap' codec can't encode characters in position 81-82: character maps to <undefined>
# 'charmap' codec can't encode characters in position 192-193: character maps to <undefined>
# 'charmap' codec can't encode characters in position 96-99: character maps to <undefined>
# 'charmap' codec can't encode characters in position 189-197: character maps to <undefined>
# 'charmap' codec can't encode characters in position 0-1: character maps to <undefined>
# 'charmap' codec can't encode characters in position 81-84: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f60a' in position 29: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f174' in position 205: character maps to <undefined>
# 'charmap' codec can't encode character '\u26a1' in position 199: character maps to <undefined>
# 'charmap' codec can't encode characters in position 263-268: character maps to <undefined>
# 'charmap' codec can't encode characters in position 309-312: character maps to <undefined>
# 'charmap' codec can't encode characters in position 180-184: character maps to <undefined>
# 'charmap' codec can't encode characters in position 358-362: character maps to <undefined>
# 'charmap' codec can't encode characters in position 327-335: character maps to <undefined>
# 'charmap' codec can't encode characters in position 109-129: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f410' in position 425: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f637' in position 94: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f609' in position 66: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f4af' in position 38: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f4aa' in position 197: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f496' in position 269: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f4de' in position 624: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f339' in position 193: character maps to <undefined>
# 'charmap' codec can't encode character '\u2716' in position 100: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f44f' in position 1: character maps to <undefined>
# 'charmap' codec can't encode character '\u2260' in position 284: character maps to <undefined>
# 'charmap' codec can't encode characters in position 235-236: character maps to <undefined>
# 'charmap' codec can't encode characters in position 34-35: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f456' in position 28: character maps to <undefined>
# 'charmap' codec can't encode characters in position 289-292: character maps to <undefined>
# 'charmap' codec can't encode characters in position 213-216: character maps to <undefined>
# 'charmap' codec can't encode characters in position 13-15: character maps to <undefined>
# 'charmap' codec can't encode characters in position 272-273: character maps to <undefined>
# 'charmap' codec can't encode characters in position 46-47: character maps to <undefined>
# 'charmap' codec can't encode character '\u2665' in position 194: character maps to <undefined>
# 'charmap' codec can't encode characters in position 348-351: character maps to <undefined>
# 'charmap' codec can't encode characters in position 258-267: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f494' in position 50: character maps to <undefined>
# 'charmap' codec can't encode characters in position 105-112: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f339' in position 225: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f4e3' in position 1: character maps to <undefined>
# 'charmap' codec can't encode characters in position 4-18: character maps to <undefined>
# 'charmap' codec can't encode characters in position 300-303: character maps to <undefined>
# 'charmap' codec can't encode characters in position 30-32: character maps to <undefined>
# 'charmap' codec can't encode characters in position 297-298: character maps to <undefined>
# 'charmap' codec can't encode characters in position 164-165: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f4f8' in position 267: character maps to <undefined>
# 'charmap' codec can't encode characters in position 175-176: character maps to <undefined>
# 'charmap' codec can't encode characters in position 14-15: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f4b0' in position 132: character maps to <undefined>
# 'charmap' codec can't encode character '\u263e' in position 308: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f618' in position 35: character maps to <undefined>
# 'charmap' codec can't encode characters in position 264-265: character maps to <undefined>
# 'charmap' codec can't encode character '\u017c' in position 138: character maps to <undefined>
# 'charmap' codec can't encode characters in position 589-592: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f602' in position 110: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f49a' in position 23: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f49b' in position 182: character maps to <undefined>
# 'charmap' codec can't encode characters in position 65-66: character maps to <undefined>
# 'charmap' codec can't encode characters in position 94-95: character maps to <undefined>
# 'charmap' codec can't encode characters in position 103-106: character maps to <undefined>
# 'charmap' codec can't encode characters in position 1-6: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f629' in position 71: character maps to <undefined>
# 'charmap' codec can't encode characters in position 0-2: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f644' in position 81: character maps to <undefined>
# 'charmap' codec can't encode characters in position 125-133: character maps to <undefined>
# 'charmap' codec can't encode characters in position 34-35: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f351' in position 340: character maps to <undefined>
# 'charmap' codec can't encode characters in position 0-3: character maps to <undefined>
# 'charmap' codec can't encode characters in position 105-106: character maps to <undefined>
# 'charmap' codec can't encode character '\u3161' in position 183: character maps to <undefined>
# 'charmap' codec can't encode characters in position 182-187: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f447' in position 53: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f384' in position 369: character maps to <undefined>
# 'charmap' codec can't encode characters in position 367-370: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f60d' in position 312: character maps to <undefined>
# 'charmap' codec can't encode characters in position 0-46: character maps to <undefined>
# 'charmap' codec can't encode character '\u2661' in position 145: character maps to <undefined>
# 'charmap' codec can't encode characters in position 366-372: character maps to <undefined>
# 'charmap' codec can't encode characters in position 33-34: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f480' in position 277: character maps to <undefined>
# 'charmap' codec can't encode characters in position 362-366: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f4af' in position 175: character maps to <undefined>
# 'charmap' codec can't encode characters in position 361-365: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f499' in position 148: character maps to <undefined>
# 'charmap' codec can't encode characters in position 4-18: character maps to <undefined>
# 'charmap' codec can't encode character '\u2066' in position 105: character maps to <undefined>
# 'charmap' codec can't encode character '\u2606' in position 299: character maps to <undefined>
# 'charmap' codec can't encode characters in position 119-121: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f48e' in position 109: character maps to <undefined>
# 'charmap' codec can't encode character '\u231a' in position 1: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f914' in position 108: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f4d6' in position 67: character maps to <undefined>
# 'charmap' codec can't encode characters in position 1-4: character maps to <undefined>
# 'charmap' codec can't encode characters in position 179-180: character maps to <undefined>
# 'charmap' codec can't encode characters in position 399-400: character maps to <undefined>
# 'charmap' codec can't encode character '\uff05' in position 94: character maps to <undefined>
# 'charmap' codec can't encode character '\ufe6a' in position 27: character maps to <undefined>
# 'charmap' codec can't encode character '\u0142' in position 6: character maps to <undefined>
# 'charmap' codec can't encode character '\u015b' in position 62: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f3f9' in position 330: character maps to <undefined>
# 'charmap' codec can't encode character '\ufe6a' in position 61: character maps to <undefined>
# 'charmap' codec can't encode character '\ufe6a' in position 49: character maps to <undefined>
# 'charmap' codec can't encode character '\u2015' in position 70: character maps to <undefined>
# 'charmap' codec can't encode characters in position 269-270: character maps to <undefined>
# 'charmap' codec can't encode characters in position 102-103: character maps to <undefined>
# 'charmap' codec can't encode characters in position 1-3: character maps to <undefined>
# 'charmap' codec can't encode character '\ufe6a' in position 95: character maps to <undefined>
# 'charmap' codec can't encode characters in position 166-168: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f60e' in position 174: character maps to <undefined>
# 'charmap' codec can't encode characters in position 1-2: character maps to <undefined>
# 'charmap' codec can't encode characters in position 181-184: character maps to <undefined>
# 'charmap' codec can't encode character '\uff05' in position 96: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f60d' in position 188: character maps to <undefined>
# ...
# 'charmap' codec can't encode character '\U0001f3c6' in position 184: character maps to <undefined>
# 'charmap' codec can't encode characters in position 0-1: character maps to <undefined>
# 'charmap' codec can't encode characters in position 35-39: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f4ab' in position 13: character maps to <undefined>
# 'charmap' codec can't encode characters in position 385-386: character maps to <undefined>
# 'charmap' codec can't encode characters in position 240-242: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f498' in position 91: character maps to <undefined>
# 'charmap' codec can't encode characters in position 332-337: character maps to <undefined>
# 'charmap' codec can't encode characters in position 322-325: character maps to <undefined>
# 'charmap' codec can't encode characters in position 341-345: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f3c6' in position 214: character maps to <undefined>
# 'charmap' codec can't encode characters in position 206-216: character maps to <undefined>
# 'charmap' codec can't encode characters in position 49-50: character maps to <undefined>
# 'charmap' codec can't encode character '\u2606' in position 193: character maps to <undefined>
# 'charmap' codec can't encode characters in position 745-748: character maps to <undefined>
# 'charmap' codec can't encode characters in position 147-148: character maps to <undefined>
# 'charmap' codec can't encode character '\u2260' in position 325: character maps to <undefined>
# 'charmap' codec can't encode characters in position 202-204: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f4cc' in position 438: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f338' in position 169: character maps to <undefined>
# 'charmap' codec can't encode characters in position 1-3: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f62c' in position 14: character maps to <undefined>
# 'charmap' codec can't encode character '\u2800' in position 110: character maps to <undefined>
# 'charmap' codec can't encode characters in position 224-227: character maps to <undefined>
# 'charmap' codec can't encode characters in position 303-305: character maps to <undefined>
# 'charmap' codec can't encode characters in position 323-324: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f62d' in position 48: character maps to <undefined>
# 'charmap' codec can't encode characters in position 153-165: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f47d' in position 305: character maps to <undefined>
# 'charmap' codec can't encode characters in position 276-279: character maps to <undefined>
# 'charmap' codec can't encode characters in position 235-238: character maps to <undefined>
# 'charmap' codec can't encode characters in position 89-90: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f97a' in position 82: character maps to <undefined>
# 'charmap' codec can't encode characters in position 206-207: character maps to <undefined>
# 'charmap' codec can't encode characters in position 88-89: character maps to <undefined>
# 'charmap' codec can't encode characters in position 89-105: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f4b0' in position 91: character maps to <undefined>
# 'charmap' codec can't encode characters in position 131-136: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f47e' in position 194: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f3a3' in position 112: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f4a5' in position 162: character maps to <undefined>
# 'charmap' codec can't encode characters in position 73-74: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f4a7' in position 325: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f974' in position 587: character maps to <undefined>
# 'charmap' codec can't encode characters in position 175-176: character maps to <undefined>
# 'charmap' codec can't encode characters in position 0-3: character maps to <undefined>
# 'charmap' codec can't encode character '\u0107' in position 37: character maps to <undefined>
# 'charmap' codec can't encode characters in position 68-69: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f49e' in position 178: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f30d' in position 593: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f694' in position 142: character maps to <undefined>
# 'charmap' codec can't encode characters in position 176-178: character maps to <undefined>
# 'charmap' codec can't encode characters in position 130-132: character maps to <undefined>
# 'charmap' codec can't encode characters in position 69-70: character maps to <undefined>
# 'charmap' codec can't encode characters in position 18-19: character maps to <undefined>
# 'charmap' codec can't encode character '\u2606' in position 181: character maps to <undefined>
# 'charmap' codec can't encode character '\u2728' in position 203: character maps to <undefined>
# 'charmap' codec can't encode characters in position 182-186: character maps to <undefined>
# 'charmap' codec can't encode characters in position 342-343: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f51e' in position 134: character maps to <undefined>
# 'charmap' codec can't encode characters in position 320-321: character maps to <undefined>
# 'charmap' codec can't encode character '\u2611' in position 91: character maps to <undefined>
# 'charmap' codec can't encode characters in position 186-187: character maps to <undefined>
# 'charmap' codec can't encode character '\u1ec5' in position 216: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f494' in position 486: character maps to <undefined>
# 'charmap' codec can't encode character '\u2763' in position 209: character maps to <undefined>
# 'charmap' codec can't encode character '\u2728' in position 785: character maps to <undefined>
# 'charmap' codec can't encode characters in position 327-332: character maps to <undefined>
# 'charmap' codec can't encode characters in position 834-837: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f499' in position 86: character maps to <undefined>
# 'charmap' codec can't encode characters in position 11-12: character maps to <undefined>
# 'charmap' codec can't encode characters in position 450-460: character maps to <undefined>
# 'charmap' codec can't encode characters in position 218-221: character maps to <undefined>
# 'charmap' codec can't encode characters in position 180-181: character maps to <undefined>
# 'charmap' codec can't encode character '\u011f' in position 13: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f928' in position 246: character maps to <undefined>
# 'charmap' codec can't encode characters in position 55-60: character maps to <undefined>
# 'charmap' codec can't encode characters in position 20-21: character maps to <undefined>
# 'charmap' codec can't encode characters in position 374-380: character maps to <undefined>
# 'charmap' codec can't encode characters in position 384-391: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f602' in position 33: character maps to <undefined>
# 'charmap' codec can't encode characters in position 145-149: character maps to <undefined>
# 'charmap' codec can't encode characters in position 49-51: character maps to <undefined>
# 'charmap' codec can't encode characters in position 321-349: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f36f' in position 155: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f928' in position 143: character maps to <undefined>
# 'charmap' codec can't encode characters in position 118-121: character maps to <undefined>
# 'charmap' codec can't encode characters in position 105-112: character maps to <undefined>
# 'charmap' codec can't encode characters in position 86-87: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f60a' in position 69: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f339' in position 111: character maps to <undefined>
# 'charmap' codec can't encode characters in position 346-350: character maps to <undefined>
# 'charmap' codec can't encode characters in position 78-82: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f98a' in position 476: character maps to <undefined>
# 'charmap' codec can't encode characters in position 101-102: character maps to <undefined>
# 'charmap' codec can't encode characters in position 650-651: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f536' in position 387: character maps to <undefined>
# 'charmap' codec can't encode characters in position 450-451: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f339' in position 283: character maps to <undefined>
# 'charmap' codec can't encode characters in position 455-456: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f538' in position 176: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f623' in position 103: character maps to <undefined>
# 'charmap' codec can't encode characters in position 10-12: character maps to <undefined>
# 'charmap' codec can't encode characters in position 234-235: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f6ab' in position 226: character maps to <undefined>
# 'charmap' codec can't encode characters in position 338-343: character maps to <undefined>
# 'charmap' codec can't encode character '\u260e' in position 293: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f527' in position 251: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f339' in position 213: character maps to <undefined>
# 'charmap' codec can't encode characters in position 465-467: character maps to <undefined>
# 'charmap' codec can't encode characters in position 78-80: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f525' in position 252: character maps to <undefined>
# 'charmap' codec can't encode characters in position 221-222: character maps to <undefined>
# 'charmap' codec can't encode characters in position 1-12: character maps to <undefined>
# 'charmap' codec can't encode characters in position 1-4: character maps to <undefined>
# 'charmap' codec can't encode characters in position 0-3: character maps to <undefined>
# 'charmap' codec can't encode character '\u20b9' in position 57: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f525' in position 33: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f52c' in position 404: character maps to <undefined>
# 'charmap' codec can't encode character '\ufe0f' in position 66: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f4af' in position 215: character maps to <undefined>
# 'charmap' codec can't encode character '\u014d' in position 91: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f440' in position 57: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f388' in position 254: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f4bb' in position 171: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f685' in position 382: character maps to <undefined>
# 'charmap' codec can't encode characters in position 86-88: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f60a' in position 73: character maps to <undefined>
# 'charmap' codec can't encode character '\U0001f4da' in position 103: character maps to <undefined>
# 'charmap' codec can't encode characters in position 728-731: character maps to <undefined>
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-17-54b49aa8fe2b> in <module>()
# ----> 1 start_mining(['Carbon free','solar' ,'global climate change', 'wind speed', 'slash and burn', 'crop burning', 'amazon fires', 'smoke', 'contamination', 'polluted', 'plastic', 'polluted Ganga', 'submerge', 'coastal areas', 'climate emergency', 'alarmism', 'environmental defence', 'climate strike', 'smog', 'breathing issues', 'greenhouse gas', 'health', 'air quality', 'fish', 'extinct', 'whales', 'sharks', 'greenhouse effect', 'CFCs', 'emission', 'carbon footprint', 'respiratory diseases', 'fossil fuels' ])
#
# <ipython-input-16-951d711489b6> in start_mining(queries)
#      27
#      28     # Run the stream object using the user defined queries
# ---> 29     stream.filter(track=queries)
#
# C:\Users\mehar\Anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     451             self.body['filter_level'] = filter_level.encode(encoding)
#     452         self.session.params = {'delimited': 'length'}
# --> 453         self._start(is_async)
#     454
#     455     def sitestream(self, follow, stall_warnings=False,
#
# C:\Users\mehar\Anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     366             self._thread.start()
#     367         else:
# --> 368             self._run()
#     369
#     370     def on_closed(self, resp):
#
# C:\Users\mehar\Anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     298             # call a handler first so that the exception can be logged.
#     299             self.listener.on_exception(exc_info[1])
# --> 300             six.reraise(*exc_info)
#     301
#     302     def _data(self, data):
#
# C:\Users\mehar\Anaconda3\lib\site-packages\six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# C:\Users\mehar\Anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     267                     self.snooze_time = self.snooze_time_step
#     268                     self.listener.on_connect()
# --> 269                     self._read_loop(resp)
#     270             except (Timeout, ssl.SSLError) as exc:
#     271                 # This is still necessary, as a SSLError can actually be
#
# C:\Users\mehar\Anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     329             next_status_obj = buf.read_len(length)
#     330             if self.running and next_status_obj:
# --> 331                 self._data(next_status_obj)
#     332
#     333             # # Note: keep-alive newlines might be inserted before each length value.
#
# C:\Users\mehar\Anaconda3\lib\site-packages\tweepy\streaming.py in _data(self, data)
#     301
#     302     def _data(self, data):
# --> 303         if self.listener.on_data(data) is False:
#     304             self.running = False
#     305
#
# C:\Users\mehar\Anaconda3\lib\site-packages\tweepy\streaming.py in on_data(self, raw_data)
#      53         if 'in_reply_to_status_id' in data:
#      54             status = Status.parse(self.api, data)
# ---> 55             if self.on_status(status) is False:
#      56                 return False
#      57         elif 'delete' in data:
#
# <ipython-input-15-b88bbcc4e3c9> in on_status(self, status)
#      54
#      55         # Open the csv file created previously
# ---> 56         csvFile = open(self.filename, 'a')
#      57
#      58         # Create a csv writer
#
# PermissionError: [Errno 13] Permission denied: 'climate_dataset_final_20191127-142026.csv'
